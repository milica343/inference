# %% [markdown]
# <a href="https://colab.research.google.com/github/milica343/inference/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sashavor/co2_inference.git
# Out:
# Cloning into 'co2_inference'...
# remote: Enumerating objects: 6661, done.
# remote: Counting objects: 100% (6661/6661), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 6661 (delta 6553), reused 6636 (delta 6528), pack-reused 0
# Receiving objects: 100% (6661/6661), 4.68 MiB | 16.09 MiB/s, done.
# Resolving deltas: 100% (6553/6553), done.

# %%
# %run /content/co2_inference/code/image_class/image_class_cifar10.py
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/endpoint_helpers.py:247: FutureWarning: 'ModelFilter' is deprecated and will be removed in huggingface_hub>=0.24. Please pass the filter parameters as keyword arguments directly to the `list_models` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Generating train split: 0 examples [00:00, ? examples/s]
# ...
# [codecarbon WARNING @ 14:27:13] Invalid gpu_ids format. Expected a string or a list of ints.
# ...

# %%
# %run /content/co2_inference/code/image_class/image_class_cifar100.py
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/endpoint_helpers.py:247: FutureWarning: 'ModelFilter' is deprecated and will be removed in huggingface_hub>=0.24. Please pass the filter parameters as keyword arguments directly to the `list_models` method.
#   warnings.warn(
# [codecarbon WARNING @ 14:54:40] Invalid gpu_ids format. Expected a string or a list of ints.
# [codecarbon INFO @ 14:54:40] [setup] RAM Tracking...
# [codecarbon INFO @ 14:54:40] [setup] GPU Tracking...
# [codecarbon INFO @ 14:54:40] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 14:54:40] [setup] CPU Tracking...
# [codecarbon WARNING @ 14:54:40] No CPU tracking mode found. Falling back on CPU constant mode.
# Model ID: google/vit-base-patch16-224
# [codecarbon INFO @ 14:54:41] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 14:54:41] >>> Tracker's metadata:
# [codecarbon INFO @ 14:54:41]   Platform system: Linux-6.1.58+-x86_64-with-glibc2.35
# ...

# %%
# %run /content/co2_inference/code/image_class/image_class_wake_vision.py
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# [codecarbon WARNING @ 16:15:21] Invalid gpu_ids format. Expected a string or a list of ints.
# [codecarbon INFO @ 16:15:21] [setup] RAM Tracking...
# [codecarbon INFO @ 16:15:21] [setup] GPU Tracking...
# [codecarbon INFO @ 16:15:21] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:15:21] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:15:21] No CPU tracking mode found. Falling back on CPU constant mode.
# Model ID: google/vit-base-patch16-224
# [codecarbon INFO @ 16:15:22] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 16:15:22] >>> Tracker's metadata:
# [codecarbon INFO @ 16:15:22]   Platform system: Linux-6.1.58+-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:15:22]   Python version: 3.10.12
# [codecarbon INFO @ 16:15:22]   CodeCarbon version: 2.4.1
# [codecarbon INFO @ 16:15:22]   Available RAM : 83.477 GB
# [codecarbon INFO @ 16:15:22]   CPU count: 12
# ...

# %%
# %run /content/co2_inference/code/textgen/textgen_oscar.py
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/endpoint_helpers.py:247: FutureWarning: 'ModelFilter' is deprecated and will be removed in huggingface_hub>=0.24. Please pass the filter parameters as keyword arguments directly to the `list_models` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# [codecarbon WARNING @ 18:42:15] Invalid gpu_ids format. Expected a string or a list of ints.
# [codecarbon INFO @ 18:42:15] [setup] RAM Tracking...
# [codecarbon INFO @ 18:42:15] [setup] GPU Tracking...
# [codecarbon INFO @ 18:42:15] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 18:42:15] [setup] CPU Tracking...
# ...

# %%
torch.cuda.memory_allocated()
# Out:
# 41193766912

# %%
torch.cuda.memory_reserved()
# Out:
# 41731227648

# %%
torch.cuda.empty_cache()
